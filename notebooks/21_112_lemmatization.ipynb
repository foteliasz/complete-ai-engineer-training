# %%
import nltk

from src.file import read

nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /Users/wojciech-
# [nltk_data]     tomaszek/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
content = read('frank_1st_para')

# %%
lem = WordNetLemmatizer()
content_lemmatized = [lem.lemmatize(word) for word in content.split()]
print(content_lemmatized)
# Out:
# ['You', 'will', 'rejoice', 'to', 'hear', 'that', 'no', 'disaster', 'ha', 'accompanied', 'the', 'commencement', 'of', 'an', 'enterprise', 'which', 'you', 'have', 'regarded', 'with', 'such', 'evil', 'forebodings.', 'I', 'arrived', 'here', 'yesterday,', 'and', 'my', 'first', 'task', 'is', 'to', 'assure', 'my', 'dear', 'sister', 'of', 'my', 'welfare', 'and', 'increasing', 'confidence', 'in', 'the', 'success', 'of', 'my', 'undertaking.']
